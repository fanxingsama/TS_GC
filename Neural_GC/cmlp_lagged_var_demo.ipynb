# %% [markdown]
# # cMLP Lagged VAR Demo
#
# - In this notebook, we train a cMLP model on linear VAR data with lagged interactions.
# - After examining the Granger causality discovery, we train a debiased model using only the discovered interactions.

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from synthetic import simulate_var
from models.cmlp import cMLP, cMLPSparse, train_model_ista, train_unregularized

# %%
# For GPU acceleration
device = torch.device('cuda')

# %%
X_np, beta, GC = simulate_var(p=10, T=1000, lag=3)
# 这里给X_np加了一维，方便满足神经网络接收数据的形式，添加的一维是batch_size=1
X = torch.tensor(X_np[np.newaxis], dtype=torch.float32, device=device)

# %%
# Plot data
fig, axarr = plt.subplots(1, 2, figsize=(16, 5))
axarr[0].plot(X_np)
axarr[0].set_xlabel('T')
axarr[0].set_title('Entire time series')
axarr[1].plot(X_np[:50])
axarr[1].set_xlabel('T')
axarr[1].set_title('First 50 time points')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Still need to tune $\lambda$ and perhaps lr

# %%
# Set up model
cmlp = cMLP(X.shape[-1], lag=5, hidden=[100]).cuda(device=device)

# %%
# Train with ISTA
train_loss_list = train_model_ista(
    cmlp, X, lam=0.002, lam_ridge=1e-2, lr=5e-2, penalty='H', max_iter=50000,
    check_every=100)
# Out:
# ----------Iter = 100----------
# Loss = 0.149696
# Variable usage = 100.00%
# ----------Iter = 200----------
# Loss = 0.144545
# Variable usage = 100.00%
# ----------Iter = 300----------
# Loss = 0.140071
# Variable usage = 100.00%
# ----------Iter = 400----------
# Loss = 0.135897
# Variable usage = 100.00%
# ----------Iter = 500----------
# Loss = 0.131900
# Variable usage = 100.00%
# ----------Iter = 600----------
# Loss = 0.128024
# Variable usage = 100.00%
# ----------Iter = 700----------
# Loss = 0.124244
# Variable usage = 100.00%
# ----------Iter = 800----------
# Loss = 0.120541
# Variable usage = 100.00%
# ----------Iter = 900----------
# Loss = 0.116907
# Variable usage = 100.00%
# ----------Iter = 1000----------
# Loss = 0.113333
# Variable usage = 100.00%
# ----------Iter = 1100----------
# Loss = 0.109816
# Variable usage = 100.00%
# ----------Iter = 1200----------
# Loss = 0.106354
# Variable usage = 100.00%
# ----------Iter = 1300----------
# Loss = 0.102945
# Variable usage = 100.00%
# ----------Iter = 1400----------
# Loss = 0.099587
# Variable usage = 100.00%
# ----------Iter = 1500----------
# Loss = 0.096283
# Variable usage = 100.00%
# ----------Iter = 1600----------
# Loss = 0.093032
# Variable usage = 100.00%
# ----------Iter = 1700----------
# Loss = 0.089835
# Variable usage = 100.00%
# ----------Iter = 1800----------
# Loss = 0.086694
# Variable usage = 100.00%
# ----------Iter = 1900----------
# Loss = 0.083611
# Variable usage = 100.00%
# ----------Iter = 2000----------
# Loss = 0.080588
# Variable usage = 100.00%
# ----------Iter = 2100----------
# Loss = 0.077628
# Variable usage = 100.00%
# ----------Iter = 2200----------
# Loss = 0.074732
# Variable usage = 100.00%
# ----------Iter = 2300----------
# Loss = 0.071904
# Variable usage = 100.00%
# ----------Iter = 2400----------
# Loss = 0.069147
# Variable usage = 100.00%
# ----------Iter = 2500----------
# Loss = 0.066464
# Variable usage = 100.00%
# ----------Iter = 2600----------
# Loss = 0.063858
# Variable usage = 100.00%
# ----------Iter = 2700----------
# Loss = 0.061333
# Variable usage = 100.00%
# ----------Iter = 2800----------
# Loss = 0.058893
# Variable usage = 100.00%
# ----------Iter = 2900----------
# Loss = 0.056543
# Variable usage = 100.00%
# ----------Iter = 3000----------
# Loss = 0.054285
# Variable usage = 100.00%
# ----------Iter = 3100----------
# Loss = 0.052125
# Variable usage = 100.00%
# ----------Iter = 3200----------
# Loss = 0.050069
# Variable usage = 100.00%
# ----------Iter = 3300----------
# Loss = 0.048130
# Variable usage = 100.00%
# ----------Iter = 3400----------
# Loss = 0.046332
# Variable usage = 100.00%
# ----------Iter = 3500----------
# Loss = 0.044689
# Variable usage = 100.00%
# ----------Iter = 3600----------
# Loss = 0.043145
# Variable usage = 100.00%
# ----------Iter = 3700----------
# Loss = 0.041667
# Variable usage = 100.00%
# ----------Iter = 3800----------
# Loss = 0.040250
# Variable usage = 100.00%
# ----------Iter = 3900----------
# Loss = 0.038898
# Variable usage = 100.00%
# ----------Iter = 4000----------
# Loss = 0.037614
# Variable usage = 100.00%
# ----------Iter = 4100----------
# Loss = 0.036418
# Variable usage = 100.00%
# ----------Iter = 4200----------
# Loss = 0.035325
# Variable usage = 100.00%
# ----------Iter = 4300----------
# Loss = 0.034327
# Variable usage = 100.00%
# ----------Iter = 4400----------
# Loss = 0.033386
# Variable usage = 100.00%
# ----------Iter = 4500----------
# Loss = 0.032488
# Variable usage = 100.00%
# ----------Iter = 4600----------
# Loss = 0.031625
# Variable usage = 100.00%
# ----------Iter = 4700----------
# Loss = 0.030795
# Variable usage = 100.00%
# ----------Iter = 4800----------
# Loss = 0.029999
# Variable usage = 100.00%
# ----------Iter = 4900----------
# Loss = 0.029238
# Variable usage = 100.00%
# ----------Iter = 5000----------
# Loss = 0.028517
# Variable usage = 100.00%
# ----------Iter = 5100----------
# Loss = 0.027847
# Variable usage = 100.00%
# ----------Iter = 5200----------
# Loss = 0.027247
# Variable usage = 100.00%
# ----------Iter = 5300----------
# Loss = 0.026704
# Variable usage = 100.00%
# ----------Iter = 5400----------
# Loss = 0.026197
# Variable usage = 100.00%
# ----------Iter = 5500----------
# Loss = 0.025713
# Variable usage = 100.00%
# ----------Iter = 5600----------
# Loss = 0.025243
# Variable usage = 100.00%
# ----------Iter = 5700----------
# Loss = 0.024786
# Variable usage = 100.00%
# ----------Iter = 5800----------
# Loss = 0.024341
# Variable usage = 100.00%
# ----------Iter = 5900----------
# Loss = 0.023909
# Variable usage = 100.00%
# ----------Iter = 6000----------
# Loss = 0.023490
# Variable usage = 100.00%
# ----------Iter = 6100----------
# Loss = 0.023083
# Variable usage = 100.00%
# ----------Iter = 6200----------
# Loss = 0.022690
# Variable usage = 100.00%
# ----------Iter = 6300----------
# Loss = 0.022312
# Variable usage = 100.00%
# ----------Iter = 6400----------
# Loss = 0.021952
# Variable usage = 100.00%
# ----------Iter = 6500----------
# Loss = 0.021613
# Variable usage = 100.00%
# ----------Iter = 6600----------
# Loss = 0.021296
# Variable usage = 100.00%
# ----------Iter = 6700----------
# Loss = 0.021014
# Variable usage = 100.00%
# ----------Iter = 6800----------
# Loss = 0.020760
# Variable usage = 100.00%
# ----------Iter = 6900----------
# Loss = 0.020532
# Variable usage = 100.00%
# ----------Iter = 7000----------
# Loss = 0.020327
# Variable usage = 100.00%
# ----------Iter = 7100----------
# Loss = 0.020134
# Variable usage = 100.00%
# ----------Iter = 7200----------
# Loss = 0.019948
# Variable usage = 100.00%
# ----------Iter = 7300----------
# Loss = 0.019766
# Variable usage = 100.00%
# ----------Iter = 7400----------
# Loss = 0.019588
# Variable usage = 100.00%
# ----------Iter = 7500----------
# Loss = 0.019413
# Variable usage = 100.00%
# ----------Iter = 7600----------
# Loss = 0.019241
# Variable usage = 100.00%
# ----------Iter = 7700----------
# Loss = 0.019071
# Variable usage = 100.00%
# ----------Iter = 7800----------
# Loss = 0.018905
# Variable usage = 100.00%
# ----------Iter = 7900----------
# Loss = 0.018740
# Variable usage = 100.00%
# ----------Iter = 8000----------
# Loss = 0.018578
# Variable usage = 100.00%
# ----------Iter = 8100----------
# Loss = 0.018418
# Variable usage = 100.00%
# ----------Iter = 8200----------
# Loss = 0.018261
# Variable usage = 100.00%
# ----------Iter = 8300----------
# Loss = 0.018105
# Variable usage = 100.00%
# ----------Iter = 8400----------
# Loss = 0.017952
# Variable usage = 100.00%
# ----------Iter = 8500----------
# Loss = 0.017800
# Variable usage = 100.00%
# ----------Iter = 8600----------
# Loss = 0.017651
# Variable usage = 100.00%
# ----------Iter = 8700----------
# Loss = 0.017505
# Variable usage = 100.00%
# ----------Iter = 8800----------
# Loss = 0.017360
# Variable usage = 100.00%
# ----------Iter = 8900----------
# Loss = 0.017218
# Variable usage = 100.00%
# ----------Iter = 9000----------
# Loss = 0.017078
# Variable usage = 100.00%
# ----------Iter = 9100----------
# Loss = 0.016941
# Variable usage = 100.00%
# ----------Iter = 9200----------
# Loss = 0.016806
# Variable usage = 100.00%
# ----------Iter = 9300----------
# Loss = 0.016677
# Variable usage = 98.00%
# ----------Iter = 9400----------
# Loss = 0.016554
# Variable usage = 95.00%
# ----------Iter = 9500----------
# Loss = 0.016441
# Variable usage = 91.00%
# ----------Iter = 9600----------
# Loss = 0.016338
# Variable usage = 89.00%
# ----------Iter = 9700----------
# Loss = 0.016244
# Variable usage = 86.00%
# ----------Iter = 9800----------
# Loss = 0.016158
# Variable usage = 83.00%
# ----------Iter = 9900----------
# Loss = 0.016081
# Variable usage = 81.00%
# ----------Iter = 10000----------
# Loss = 0.016010
# Variable usage = 78.00%
# ----------Iter = 10100----------
# Loss = 0.015950
# Variable usage = 74.00%
# ----------Iter = 10200----------
# Loss = 0.015898
# Variable usage = 68.00%
# ----------Iter = 10300----------
# Loss = 0.015857
# Variable usage = 63.00%
# ----------Iter = 10400----------
# Loss = 0.015826
# Variable usage = 57.00%
# ----------Iter = 10500----------
# Loss = 0.015800
# Variable usage = 53.00%
# ----------Iter = 10600----------
# Loss = 0.015780
# Variable usage = 49.00%
# ----------Iter = 10700----------
# Loss = 0.015762
# Variable usage = 47.00%
# ----------Iter = 10800----------
# Loss = 0.015746
# Variable usage = 46.00%
# ----------Iter = 10900----------
# Loss = 0.015731
# Variable usage = 45.00%
# ----------Iter = 11000----------
# Loss = 0.015719
# Variable usage = 43.00%
# ----------Iter = 11100----------
# Loss = 0.015708
# Variable usage = 42.00%
# ----------Iter = 11200----------
# Loss = 0.015697
# Variable usage = 42.00%
# ----------Iter = 11300----------
# Loss = 0.015688
# Variable usage = 40.00%
# ----------Iter = 11400----------
# Loss = 0.015680
# Variable usage = 40.00%
# ----------Iter = 11500----------
# Loss = 0.015672
# Variable usage = 40.00%
# ----------Iter = 11600----------
# Loss = 0.015665
# Variable usage = 39.00%
# ----------Iter = 11700----------
# Loss = 0.015659
# Variable usage = 38.00%
# ----------Iter = 11800----------
# Loss = 0.015653
# Variable usage = 38.00%
# ----------Iter = 11900----------
# Loss = 0.015647
# Variable usage = 36.00%
# ----------Iter = 12000----------
# Loss = 0.015642
# Variable usage = 36.00%
# ----------Iter = 12100----------
# Loss = 0.015638
# Variable usage = 36.00%
# ----------Iter = 12200----------
# Loss = 0.015633
# Variable usage = 36.00%
# ----------Iter = 12300----------
# Loss = 0.015629
# Variable usage = 35.00%
# ----------Iter = 12400----------
# Loss = 0.015625
# Variable usage = 35.00%
# ----------Iter = 12500----------
# Loss = 0.015621
# Variable usage = 35.00%
# ----------Iter = 12600----------
# Loss = 0.015618
# Variable usage = 35.00%
# ----------Iter = 12700----------
# Loss = 0.015614
# Variable usage = 33.00%
# ----------Iter = 12800----------
# Loss = 0.015611
# Variable usage = 33.00%
# ----------Iter = 12900----------
# Loss = 0.015609
# Variable usage = 32.00%
# ----------Iter = 13000----------
# Loss = 0.015606
# Variable usage = 31.00%
# ----------Iter = 13100----------
# Loss = 0.015604
# Variable usage = 31.00%
# ----------Iter = 13200----------
# Loss = 0.015602
# Variable usage = 31.00%
# ----------Iter = 13300----------
# Loss = 0.015599
# Variable usage = 31.00%
# ----------Iter = 13400----------
# Loss = 0.015597
# Variable usage = 31.00%
# ----------Iter = 13500----------
# Loss = 0.015596
# Variable usage = 30.00%
# ----------Iter = 13600----------
# Loss = 0.015594
# Variable usage = 30.00%
# ----------Iter = 13700----------
# Loss = 0.015592
# Variable usage = 30.00%
# ----------Iter = 13800----------
# Loss = 0.015590
# Variable usage = 30.00%
# ----------Iter = 13900----------
# Loss = 0.015589
# Variable usage = 30.00%
# ----------Iter = 14000----------
# Loss = 0.015587
# Variable usage = 29.00%
# ----------Iter = 14100----------
# Loss = 0.015586
# Variable usage = 29.00%
# ----------Iter = 14200----------
# Loss = 0.015585
# Variable usage = 28.00%
# ----------Iter = 14300----------
# Loss = 0.015584
# Variable usage = 28.00%
# ----------Iter = 14400----------
# Loss = 0.015582
# Variable usage = 28.00%
# ----------Iter = 14500----------
# Loss = 0.015581
# Variable usage = 28.00%
# ----------Iter = 14600----------
# Loss = 0.015580
# Variable usage = 28.00%
# ----------Iter = 14700----------
# Loss = 0.015579
# Variable usage = 28.00%
# ----------Iter = 14800----------
# Loss = 0.015578
# Variable usage = 28.00%
# ----------Iter = 14900----------
# Loss = 0.015577
# Variable usage = 28.00%
# ----------Iter = 15000----------
# Loss = 0.015577
# Variable usage = 28.00%
# ----------Iter = 15100----------
# Loss = 0.015576
# Variable usage = 28.00%
# ----------Iter = 15200----------
# Loss = 0.015575
# Variable usage = 28.00%
# ----------Iter = 15300----------
# Loss = 0.015574
# Variable usage = 28.00%
# ----------Iter = 15400----------
# Loss = 0.015573
# Variable usage = 28.00%
# ----------Iter = 15500----------
# Loss = 0.015573
# Variable usage = 27.00%
# ----------Iter = 15600----------
# Loss = 0.015572
# Variable usage = 27.00%
# ----------Iter = 15700----------
# Loss = 0.015571
# Variable usage = 27.00%
# ----------Iter = 15800----------
# Loss = 0.015571
# Variable usage = 26.00%
# ----------Iter = 15900----------
# Loss = 0.015570
# Variable usage = 26.00%
# ----------Iter = 16000----------
# Loss = 0.015570
# Variable usage = 26.00%
# ----------Iter = 16100----------
# Loss = 0.015569
# Variable usage = 26.00%
# ----------Iter = 16200----------
# Loss = 0.015569
# Variable usage = 26.00%
# ----------Iter = 16300----------
# Loss = 0.015568
# Variable usage = 26.00%
# ----------Iter = 16400----------
# Loss = 0.015568
# Variable usage = 26.00%
# ----------Iter = 16500----------
# Loss = 0.015567
# Variable usage = 26.00%
# ----------Iter = 16600----------
# Loss = 0.015567
# Variable usage = 26.00%
# ----------Iter = 16700----------
# Loss = 0.015567
# Variable usage = 26.00%
# ----------Iter = 16800----------
# Loss = 0.015566
# Variable usage = 26.00%
# ----------Iter = 16900----------
# Loss = 0.015566
# Variable usage = 26.00%
# ----------Iter = 17000----------
# Loss = 0.015566
# Variable usage = 26.00%
# ----------Iter = 17100----------
# Loss = 0.015565
# Variable usage = 26.00%
# ----------Iter = 17200----------
# Loss = 0.015565
# Variable usage = 26.00%
# ----------Iter = 17300----------
# Loss = 0.015565
# Variable usage = 26.00%
# ----------Iter = 17400----------
# Loss = 0.015564
# Variable usage = 26.00%
# ----------Iter = 17500----------
# Loss = 0.015564
# Variable usage = 26.00%
# ----------Iter = 17600----------
# Loss = 0.015564
# Variable usage = 26.00%
# ----------Iter = 17700----------
# Loss = 0.015564
# Variable usage = 26.00%
# ----------Iter = 17800----------
# Loss = 0.015563
# Variable usage = 26.00%
# ----------Iter = 17900----------
# Loss = 0.015563
# Variable usage = 26.00%
# ----------Iter = 18000----------
# Loss = 0.015563
# Variable usage = 26.00%
# ----------Iter = 18100----------
# Loss = 0.015563
# Variable usage = 26.00%
# ----------Iter = 18200----------
# Loss = 0.015562
# Variable usage = 26.00%
# ----------Iter = 18300----------
# Loss = 0.015562
# Variable usage = 26.00%
# ----------Iter = 18400----------
# Loss = 0.015562
# Variable usage = 26.00%
# ----------Iter = 18500----------
# Loss = 0.015562
# Variable usage = 26.00%
# ----------Iter = 18600----------
# Loss = 0.015562
# Variable usage = 26.00%
# ----------Iter = 18700----------
# Loss = 0.015561
# Variable usage = 26.00%
# ----------Iter = 18800----------
# Loss = 0.015561
# Variable usage = 26.00%
# ----------Iter = 18900----------
# Loss = 0.015561
# Variable usage = 26.00%
# ----------Iter = 19000----------
# Loss = 0.015561
# Variable usage = 26.00%
# ----------Iter = 19100----------
# Loss = 0.015561
# Variable usage = 26.00%
# ----------Iter = 19200----------
# Loss = 0.015561
# Variable usage = 26.00%
# ----------Iter = 19300----------
# Loss = 0.015561
# Variable usage = 26.00%
# ----------Iter = 19400----------
# Loss = 0.015560
# Variable usage = 26.00%
# ----------Iter = 19500----------
# Loss = 0.015560
# Variable usage = 26.00%
# ----------Iter = 19600----------
# Loss = 0.015560
# Variable usage = 26.00%
# ----------Iter = 19700----------
# Loss = 0.015560
# Variable usage = 26.00%
# ----------Iter = 19800----------
# Loss = 0.015560
# Variable usage = 26.00%
# ----------Iter = 19900----------
# Loss = 0.015560
# Variable usage = 26.00%
# ----------Iter = 20000----------
# Loss = 0.015560
# Variable usage = 26.00%
# ----------Iter = 20100----------
# Loss = 0.015560
# Variable usage = 26.00%
# ----------Iter = 20200----------
# Loss = 0.015560
# Variable usage = 26.00%
# ----------Iter = 20300----------
# Loss = 0.015559
# Variable usage = 26.00%
# ----------Iter = 20400----------
# Loss = 0.015559
# Variable usage = 26.00%
# ----------Iter = 20500----------
# Loss = 0.015559
# Variable usage = 26.00%
# ----------Iter = 20600----------
# Loss = 0.015559
# Variable usage = 26.00%
# ----------Iter = 20700----------
# Loss = 0.015559
# Variable usage = 25.00%
# ----------Iter = 20800----------
# Loss = 0.015559
# Variable usage = 25.00%
# ----------Iter = 20900----------
# Loss = 0.015559
# Variable usage = 25.00%
# ----------Iter = 21000----------
# Loss = 0.015559
# Variable usage = 25.00%
# ----------Iter = 21100----------
# Loss = 0.015559
# Variable usage = 25.00%
# ----------Iter = 21200----------
# Loss = 0.015559
# Variable usage = 25.00%
# ----------Iter = 21300----------
# Loss = 0.015559
# Variable usage = 25.00%
# ----------Iter = 21400----------
# Loss = 0.015559
# Variable usage = 24.00%
# ----------Iter = 21500----------
# Loss = 0.015559
# Variable usage = 24.00%
# ----------Iter = 21600----------
# Loss = 0.015559
# Variable usage = 24.00%
# ----------Iter = 21700----------
# Loss = 0.015559
# Variable usage = 24.00%
# ----------Iter = 21800----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 21900----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 22000----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 22100----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 22200----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 22300----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 22400----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 22500----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 22600----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 22700----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 22800----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 22900----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 23000----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 23100----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 23200----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 23300----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 23400----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 23500----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 23600----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 23700----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 23800----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 23900----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 24000----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 24100----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 24200----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 24300----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 24400----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 24500----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 24600----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 24700----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 24800----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 24900----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 25000----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 25100----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 25200----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 25300----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 25400----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 25500----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 25600----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 25700----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 25800----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 25900----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 26000----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 26100----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 26200----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 26300----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 26400----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 26500----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 26600----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 26700----------
# Loss = 0.015558
# Variable usage = 24.00%
# ----------Iter = 26800----------
# Loss = 0.015557
# Variable usage = 24.00%
# ----------Iter = 26900----------
# Loss = 0.015557
# Variable usage = 24.00%
# ----------Iter = 27000----------
# Loss = 0.015557
# Variable usage = 24.00%
# ----------Iter = 27100----------
# Loss = 0.015557
# Variable usage = 24.00%
# ----------Iter = 27200----------
# Loss = 0.015557
# Variable usage = 24.00%
# ----------Iter = 27300----------
# Loss = 0.015557
# Variable usage = 24.00%
# ----------Iter = 27400----------
# Loss = 0.015557
# Variable usage = 24.00%
# ----------Iter = 27500----------
# Loss = 0.015557
# Variable usage = 24.00%
# ----------Iter = 27600----------
# Loss = 0.015557
# Variable usage = 24.00%
# ----------Iter = 27700----------
# Loss = 0.015557
# Variable usage = 24.00%
# ----------Iter = 27800----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 27900----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 28000----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 28100----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 28200----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 28300----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 28400----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 28500----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 28600----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 28700----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 28800----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 28900----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 29000----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 29100----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 29200----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 29300----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 29400----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 29500----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 29600----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 29700----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 29800----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 29900----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 30000----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 30100----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 30200----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 30300----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 30400----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 30500----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 30600----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 30700----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 30800----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 30900----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 31000----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 31100----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 31200----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 31300----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 31400----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 31500----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 31600----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 31700----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 31800----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 31900----------
# Loss = 0.015557
# Variable usage = 23.00%
# ----------Iter = 32000----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 32100----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 32200----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 32300----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 32400----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 32500----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 32600----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 32700----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 32800----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 32900----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 33000----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 33100----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 33200----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 33300----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 33400----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 33500----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 33600----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 33700----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 33800----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 33900----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 34000----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 34100----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 34200----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 34300----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 34400----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 34500----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 34600----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 34700----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 34800----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 34900----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 35000----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 35100----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 35200----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 35300----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 35400----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 35500----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 35600----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 35700----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 35800----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 35900----------
# Loss = 0.015557
# Variable usage = 22.00%
# ----------Iter = 36000----------
# Loss = 0.015557
# Variable usage = 22.00%
# Stopping early

# %%
# Loss function plot
plt.figure(figsize=(8, 5))
plt.plot(50 * np.arange(len(train_loss_list)), [loss.item() for loss in train_loss_list])
plt.title('cMLP training')
plt.ylabel('Loss')
plt.xlabel('Training steps')
plt.tight_layout()
plt.show()

# %%
# Verify learned Granger causality
GC_est = cmlp.GC().cpu().data.numpy() # 提取学习到的因果矩阵

print('True variable usage = %.2f%%' % (100 * np.mean(GC))) # 计算实际因果矩阵 GC 中非零元素的比例，表示实际的变量使用率。
print('Estimated variable usage = %.2f%%' % (100 * np.mean(GC_est))) # 计算估计因果矩阵 GC_est中非零元素的比例，表示估计的变量使用率。
print('Accuracy = %.2f%%' % (100 * np.mean(GC == GC_est))) # 计算实际因果矩阵和估计因果矩阵之间一致的比例，表示模型的准确率。

#  可视化实际的因果矩阵
fig, axarr = plt.subplots(1, 2, figsize=(16, 5))
axarr[0].imshow(GC, cmap='Blues')
axarr[0].set_title('GC actual')
axarr[0].set_ylabel('Affected series')
axarr[0].set_xlabel('Causal series')
axarr[0].set_xticks([])
axarr[0].set_yticks([])

#  可视化学习到的因果矩阵
axarr[1].imshow(GC_est, cmap='Blues', vmin=0, vmax=1, extent=(0, len(GC_est), len(GC_est), 0))
axarr[1].set_title('GC estimated')
axarr[1].set_ylabel('Affected series')
axarr[1].set_xlabel('Causal series')
axarr[1].set_xticks([])
axarr[1].set_yticks([])

# 标记不一致的因果关系
for i in range(len(GC_est)):
    for j in range(len(GC_est)):
        if GC[i, j] != GC_est[i, j]:
            rect = plt.Rectangle((j, i-0.05), 1, 1, facecolor='none', edgecolor='red', linewidth=1)
            axarr[1].add_patch(rect)
plt.show()
# Out:
# True variable usage = 20.00%
# Estimated variable usage = 22.00%
# Accuracy = 98.00%

# %%
# Verify lag selection
for i in range(len(GC_est)):
    # Get true GC
    GC_lag = np.zeros((5, len(GC_est)))
    GC_lag[:3, GC[i].astype(bool)] = 1.0

    # Get estimated GC
    GC_est_lag = cmlp.GC(ignore_lag=False, threshold=False)[i].cpu().data.numpy().T[::-1]

    # Make figures
    fig, axarr = plt.subplots(1, 2, figsize=(16, 5))
    axarr[0].imshow(GC_lag, cmap='Blues', extent=(0, len(GC_est), 5, 0))
    axarr[0].set_title('Series %d true GC' % (i + 1))
    axarr[0].set_ylabel('Lag')
    axarr[0].set_xlabel('Series')
    axarr[0].set_xticks(np.arange(len(GC_est)) + 0.5)
    axarr[0].set_xticklabels(range(len(GC_est)))
    axarr[0].set_yticks(np.arange(5) + 0.5)
    axarr[0].set_yticklabels(range(1, 5 + 1))
    axarr[0].tick_params(axis='both', length=0)

    axarr[1].imshow(GC_est_lag, cmap='Blues', extent=(0, len(GC_est), 5, 0))
    axarr[1].set_title('Series %d estimated GC' % (i + 1))
    axarr[1].set_ylabel('Lag')
    axarr[1].set_xlabel('Series')
    axarr[1].set_xticks(np.arange(len(GC_est)) + 0.5)
    axarr[1].set_xticklabels(range(len(GC_est)))
    axarr[1].set_yticks(np.arange(5) + 0.5)
    axarr[1].set_yticklabels(range(1, 5 + 1))
    axarr[1].tick_params(axis='both', length=0)

    # Mark nonzeros
    for i in range(len(GC_est)):
        for j in range(5):
            if GC_est_lag[j, i] > 0.0:
                rect = plt.Rectangle((i, j), 1, 1, facecolor='none', edgecolor='green', linewidth=1.0)
                axarr[1].add_patch(rect)

    plt.show()

# %% [markdown]
# # Train sparsified model

# %%
# Create a debiased model
sparsity = cmlp.GC().bool()
cmlp_sparse = cMLPSparse(X.shape[-1], sparsity, lag=5, hidden=[100]).cuda(device=device)

# Train
train_loss_list = train_unregularized(cmlp_sparse, X, lr=1e-3, max_iter=10000,
                                      check_every=100, verbose=1)
# Out:
# ----------Iter = 100----------
# Loss = 0.009646
# ----------Iter = 200----------
# Loss = 0.009011
# ----------Iter = 300----------
# Loss = 0.008380
# ----------Iter = 400----------
# Loss = 0.007822
# ----------Iter = 500----------
# Loss = 0.007336
# ----------Iter = 600----------
# Loss = 0.006912
# ----------Iter = 700----------
# Loss = 0.006543
# ----------Iter = 800----------
# Loss = 0.006200
# ----------Iter = 900----------
# Loss = 0.005872
# ----------Iter = 1000----------
# Loss = 0.005574
# ----------Iter = 1100----------
# Loss = 0.005300
# ----------Iter = 1200----------
# Loss = 0.005052
# ----------Iter = 1300----------
# Loss = 0.004839
# ----------Iter = 1400----------
# Loss = 0.004629
# ----------Iter = 1500----------
# Loss = 0.004451
# ----------Iter = 1600----------
# Loss = 0.004291
# ----------Iter = 1700----------
# Loss = 0.004134
# ----------Iter = 1800----------
# Loss = 0.003977
# ----------Iter = 1900----------
# Loss = 0.003833
# ----------Iter = 2000----------
# Loss = 0.003703
# ----------Iter = 2100----------
# Loss = 0.003580
# ----------Iter = 2200----------
# Loss = 0.003462
# ----------Iter = 2300----------
# Loss = 0.003347
# ----------Iter = 2400----------
# Loss = 0.003233
# ----------Iter = 2500----------
# Loss = 0.003125
# ----------Iter = 2600----------
# Loss = 0.003030
# ----------Iter = 2700----------
# Loss = 0.002948
# ----------Iter = 2800----------
# Loss = 0.002868
# ----------Iter = 2900----------
# Loss = 0.002793
# ----------Iter = 3000----------
# Loss = 0.002723
# ----------Iter = 3100----------
# Loss = 0.002657
# ----------Iter = 3200----------
# Loss = 0.002595
# ----------Iter = 3300----------
# Loss = 0.002538
# ----------Iter = 3400----------
# Loss = 0.002486
# ----------Iter = 3500----------
# Loss = 0.002433
# ----------Iter = 3600----------
# Loss = 0.002382
# ----------Iter = 3700----------
# Loss = 0.002338
# ----------Iter = 3800----------
# Loss = 0.002293
# ----------Iter = 3900----------
# Loss = 0.002252
# ----------Iter = 4000----------
# Loss = 0.002211
# ----------Iter = 4100----------
# Loss = 0.002174
# ----------Iter = 4200----------
# Loss = 0.002137
# ----------Iter = 4300----------
# Loss = 0.002100
# ----------Iter = 4400----------
# Loss = 0.002067
# ----------Iter = 4500----------
# Loss = 0.002037
# ----------Iter = 4600----------
# Loss = 0.002009
# ----------Iter = 4700----------
# Loss = 0.001982
# ----------Iter = 4800----------
# Loss = 0.001958
# ----------Iter = 4900----------
# Loss = 0.001932
# ----------Iter = 5000----------
# Loss = 0.001909
# ----------Iter = 5100----------
# Loss = 0.001890
# ----------Iter = 5200----------
# Loss = 0.001869
# ----------Iter = 5300----------
# Loss = 0.001846
# ----------Iter = 5400----------
# Loss = 0.001829
# ----------Iter = 5500----------
# Loss = 0.001810
# ----------Iter = 5600----------
# Loss = 0.001794
# ----------Iter = 5700----------
# Loss = 0.001778
# ----------Iter = 5800----------
# Loss = 0.001761
# ----------Iter = 5900----------
# Loss = 0.001747
# ----------Iter = 6000----------
# Loss = 0.001731
# ----------Iter = 6100----------
# Loss = 0.001714
# ----------Iter = 6200----------
# Loss = 0.001699
# ----------Iter = 6300----------
# Loss = 0.001682
# ----------Iter = 6400----------
# Loss = 0.001668
# ----------Iter = 6500----------
# Loss = 0.001649
# ----------Iter = 6600----------
# Loss = 0.001635
# ----------Iter = 6700----------
# Loss = 0.001620
# ----------Iter = 6800----------
# Loss = 0.001605
# ----------Iter = 6900----------
# Loss = 0.001589
# ----------Iter = 7000----------
# Loss = 0.001574
# ----------Iter = 7100----------
# Loss = 0.001559
# ----------Iter = 7200----------
# Loss = 0.001548
# ----------Iter = 7300----------
# Loss = 0.001536
# ----------Iter = 7400----------
# Loss = 0.001523
# ----------Iter = 7500----------
# Loss = 0.001512
# ----------Iter = 7600----------
# Loss = 0.001501
# ----------Iter = 7700----------
# Loss = 0.001489
# ----------Iter = 7800----------
# Loss = 0.001479
# ----------Iter = 7900----------
# Loss = 0.001469
# ----------Iter = 8000----------
# Loss = 0.001459
# ----------Iter = 8100----------
# Loss = 0.001450
# ----------Iter = 8200----------
# Loss = 0.001440
# ----------Iter = 8300----------
# Loss = 0.001430
# ----------Iter = 8400----------
# Loss = 0.001421
# ----------Iter = 8500----------
# Loss = 0.001411
# ----------Iter = 8600----------
# Loss = 0.001400
# ----------Iter = 8700----------
# Loss = 0.001393
# ----------Iter = 8800----------
# Loss = 0.001382
# ----------Iter = 8900----------
# Loss = 0.001375
# ----------Iter = 9000----------
# Loss = 0.001367
# ----------Iter = 9100----------
# Loss = 0.001360
# ----------Iter = 9200----------
# Loss = 0.001352
# ----------Iter = 9300----------
# Loss = 0.001343
# ----------Iter = 9400----------
# Loss = 0.001337
# ----------Iter = 9500----------
# Loss = 0.001331
# ----------Iter = 9600----------
# Loss = 0.001324
# ----------Iter = 9700----------
# Loss = 0.001315
# ----------Iter = 9800----------
# Loss = 0.001311
# ----------Iter = 9900----------
# Loss = 0.001304
# ----------Iter = 10000----------
# Loss = 0.001298

# %%
# Plot loss function
plt.figure(figsize=(10, 5))
plt.title('Debiased model training')
plt.ylabel('Loss')
plt.xlabel('Training steps')
plt.plot(100 * np.arange(len(train_loss_list)), [loss.item() for loss in train_loss_list])
plt.show()

# %%
# Get optimal forecasts using VAR parameters
X_optimal_forecast = np.zeros((X.shape[-1], 1000-3))
for t in range(1000-3):
    X_optimal_forecast[:, t] = np.dot(beta, X_np.T[:, t:(t+3)].flatten(order='F'))
X_optimal_forecast = X_optimal_forecast.T

# Forecast using debiased cMLP
X_pred = cmlp_sparse(X)

# Plot actual data and forecasts
num_points = 25

for i in range(X.shape[-1]):
    plt.figure(figsize=(10, 5))
    plt.plot(X[0, 3:num_points+3, i].cpu().data.numpy(), label='Actual')
    plt.plot(X_pred[0, :num_points, i].cpu().data.numpy(), label='cMLP forecasting')
    plt.plot(X_optimal_forecast[:num_points, i], label='Optimal forecasting')
    plt.legend(loc='upper right')
    plt.title('Series %d forecasting' % (i + 1))
    plt.show()
